# %%
import pandas as pd
import numpy as np
import re

# %%
users1 = pd.read_csv('Mbear.csv')
del users1['Unnamed: 0']

users2 = pd.read_csv('Nast_01.csv')
del users2['Unnamed: 0']

users3 = pd.read_csv('Nast_02.csv')
del users3['Unnamed: 0']

users4 = pd.read_csv('Restau.csv')
del users4['Unnamed: 0']

users5 = pd.read_csv('Restau2-5.csv')
del users5['Unnamed: 0']

users6 = pd.read_csv('Restau2.csv')
del users6['Unnamed: 0']

users7 = pd.read_csv('Restau3-5.csv')
del users7['Unnamed: 0']

users8 = pd.read_csv('Restau3.csv')
del users8['Unnamed: 0']

users9 = pd.read_csv('Restau4-5.csv')
del users9['Unnamed: 0']

users10 = pd.read_csv('Restau4.csv')
del users10['Unnamed: 0']

users11 = pd.read_csv('Restau5-5.csv')
del users11['Unnamed: 0']

users12 = pd.read_csv('Restau5-55.csv')
del users12['Unnamed: 0']

users13 = pd.read_csv('Restau5.csv')
del users13['Unnamed: 0']

users14 = pd.read_csv('Restau6-5.csv')
del users14['Unnamed: 0']

users15 = pd.read_csv('Restau6.csv')
del users15['Unnamed: 0']

users16 = pd.read_csv('Restau7-5.csv')
del users16['Unnamed: 0']

users17 = pd.read_csv('Restau7.csv')
del users17['Unnamed: 0']

users18 = pd.read_csv('Restau8.csv')
del users18['Unnamed: 0']

users19 = pd.read_csv('restau_0.csv')
del users19['Unnamed: 0']

users20 = pd.read_csv('restau_01.csv')
del users20['Unnamed: 0']

users21 = pd.read_csv('restau_02.csv')
del users21['Unnamed: 0']

users22 = pd.read_csv('Nast_03.csv')
del users22['Unnamed: 0']


xc = pd.read_csv('restau_london_final.csv')
del xc['Unnamed: 0']

#del users1['Url']
users1.head()
# Out:
#                                  Name                 Restaurant  \
# 0  Dr_Rebecca_PLondon, United Kingdom  Street Feast Model Market
# 1         Karen GKent, United Kingdom  Street Feast Model Market
# 2       MelMayBLondon, United Kingdom  Street Feast Model Market
# 3         madfordrMississauga,Ontario  Street Feast Model Market
# 4      kerlee18London, United Kingdom  Street Feast Model Market
#
#                                              Rating
# 0  <span class="ui_bubble_rating bubble_40"></span>
# 1  <span class="ui_bubble_rating bubble_20"></span>
# 2  <span class="ui_bubble_rating bubble_30"></span>
# 3  <span class="ui_bubble_rating bubble_50"></span>
# 4  <span class="ui_bubble_rating bubble_40"></span>

# %%
users23 = pd.read_csv('Mbear2.csv')
del users23['Unnamed: 0']

users24 = pd.read_csv('Mbear3.csv')
del users24['Unnamed: 0']

users25 = pd.read_csv('Mbear4.csv')
del users25['Unnamed: 0']

users26 = pd.read_csv('Mbear4-5.csv')
del users26['Unnamed: 0']

users27 = pd.read_csv('Mbear5.csv')
del users27['Unnamed: 0']

users28 = pd.read_csv('Mbear6.csv')
del users28['Unnamed: 0']

users29 = pd.read_csv('Mbear7.csv')
del users29['Unnamed: 0']

users30 = pd.read_csv('Mbear8.csv')
del users30['Unnamed: 0']

users91 = pd.read_csv('Mbear9.csv')
del users91['Unnamed: 0']

users31 = pd.read_csv('Mbear10.csv')
del users31['Unnamed: 0']

users32 = pd.read_csv('Yimi.csv')
del users32['Unnamed: 0']

users33 = pd.read_csv('Mbear12.csv')
del users33['Unnamed: 0']

users34 = pd.read_csv('Mbear13.csv')
del users34['Unnamed: 0']

users35 = pd.read_csv('Mbear14.csv')
del users35['Unnamed: 0']

users36 = pd.read_csv('Mbear15.csv')
del users36['Unnamed: 0']

users37 = pd.read_csv('Mbear16.csv')
del users37['Unnamed: 0']

users38 = pd.read_csv('Mbear17.csv')
del users38['Unnamed: 0']

users39 = pd.read_csv('Mbear18.csv')
del users39['Unnamed: 0']

users40 = pd.read_csv('Mbear19.csv')
del users40['Unnamed: 0']

users41 = pd.read_csv('Mbear20.csv')
del users41['Unnamed: 0']

users42 = pd.read_csv('Mbear21.csv')
del users42['Unnamed: 0']

users43 = pd.read_csv('Mbear22.csv')
del users43['Unnamed: 0']

users44 = pd.read_csv('Mbear23.csv')
del users44['Unnamed: 0']

users45 = pd.read_csv('Mbear24.csv')
del users45['Unnamed: 0']

users23.head()
# Out:
#                                         Name      Restaurant  \
# 0                    dannekomaSavsjo, Sweden  The Distillery
# 1  0911janicebBuckhurst Hill, United Kingdom  The Distillery
# 2                                   Hilary B  The Distillery
# 3            Jon EWarminster, United Kingdom  The Distillery
# 4            City2RH2Reigate, United Kingdom  The Distillery
#
#                                              Rating
# 0  <span class="ui_bubble_rating bubble_50"></span>
# 1  <span class="ui_bubble_rating bubble_50"></span>
# 2  <span class="ui_bubble_rating bubble_20"></span>
# 3  <span class="ui_bubble_rating bubble_50"></span>
# 4  <span class="ui_bubble_rating bubble_40"></span>

# %%
users46 = pd.read_csv('Restau8-5.csv')
del users46['Unnamed: 0']

users47 = pd.read_csv('Restau9.csv')
del users47['Unnamed: 0']

users48 = pd.read_csv('Kollz1.csv')
del users48['Unnamed: 0']

users49 = pd.read_csv('Kollz2.csv')
del users49['Unnamed: 0']

users50 = pd.read_csv('Kollz25.csv')
del users50['Unnamed: 0']

users51 = pd.read_csv('Kollz3.csv')
del users51['Unnamed: 0']

users52 = pd.read_csv('Kollz35.csv')
del users52['Unnamed: 0']

users53 = pd.read_csv('Nast_03.csv')
del users53['Unnamed: 0']

users54 = pd.read_csv('Nast_04.csv')
del users54['Unnamed: 0']

users55 = pd.read_csv('Nast_05.csv')
del users55['Unnamed: 0']

users56 = pd.read_csv('Nast_06.csv')
del users56['Unnamed: 0']

users57 = pd.read_csv('Nast_06-5.csv')
del users57['Unnamed: 0']

users58 = pd.read_csv('Nast_07.csv')
del users58['Unnamed: 0']

users59 = pd.read_csv('Nast_08.csv')
del users59['Unnamed: 0']

users60 = pd.read_csv('Nast_09.csv')
del users60['Unnamed: 0']

users61 = pd.read_csv('Nast_10.csv')
del users61['Unnamed: 0']

users62 = pd.read_csv('Nast_11.csv')
del users62['Unnamed: 0']

users63 = pd.read_csv('Nast_12.csv')
del users63['Unnamed: 0']

users64 = pd.read_csv('Nast_13.csv')
del users64['Unnamed: 0']

users65 = pd.read_csv('Nast_14.csv')
del users65['Unnamed: 0']

users66 = pd.read_csv('Nast_15.csv')
del users66['Unnamed: 0']

users67 = pd.read_csv('Nast_155.csv')
del users67['Unnamed: 0']

users68 = pd.read_csv('Nast_1555.csv')
del users68['Unnamed: 0']

users69 = pd.read_csv('Nast_085.csv')
del users69['Unnamed: 0']

users70 = pd.read_csv('Nast_95.csv')
del users70['Unnamed: 0']


users46.head()
# Out:
#                                          Name Restaurant  \
# 0                   HazelB114Gentilly, France    MAMIE'S
# 1  TonksMeowWeston-super-Mare, United Kingdom    MAMIE'S
# 2               kyecoleLondon, United Kingdom    MAMIE'S
# 3                                     Rosie S    MAMIE'S
# 4               AMK1988London, United Kingdom    MAMIE'S
#
#                                              Rating
# 0  <span class="ui_bubble_rating bubble_40"></span>
# 1  <span class="ui_bubble_rating bubble_50"></span>
# 2  <span class="ui_bubble_rating bubble_40"></span>
# 3  <span class="ui_bubble_rating bubble_30"></span>
# 4  <span class="ui_bubble_rating bubble_40"></span>

# %%
users71 = pd.read_csv('Yimi2.csv')
del users71['Unnamed: 0']

users72 = pd.read_csv('Yimi3.csv')
del users72['Unnamed: 0']

users73 = pd.read_csv('Yimi3-5.csv')
del users73['Unnamed: 0']

users74 = pd.read_csv('Yimi4.csv')
del users74['Unnamed: 0']

users75 = pd.read_csv('Yimi42.csv')
del users75['Unnamed: 0']

users76 = pd.read_csv('Yimi422.csv')
del users76['Unnamed: 0']

users77 = pd.read_csv('Yimi423.csv')
del users77['Unnamed: 0']

users78 = pd.read_csv('Yimi5.csv')
del users78['Unnamed: 0']

users79 = pd.read_csv('Yimi6.csv')
del users79['Unnamed: 0']

users80 = pd.read_csv('Yimi10.csv')
del users80['Unnamed: 0']

users81 = pd.read_csv('Yimi55.csv')
del users81['Unnamed: 0']

users82 = pd.read_csv('Yimi68oo.csv')
del users82['Unnamed: 0']

users83 = pd.read_csv('Sagar1.csv')
del users83['Unnamed: 0']

users84 = pd.read_csv('Sagar1-2.csv')
del users84['Unnamed: 0']

users85 = pd.read_csv('Sagar2.csv')
del users85['Unnamed: 0']

users86 = pd.read_csv('Sagar3.csv')
del users86['Unnamed: 0']

users87 = pd.read_csv('Sagar3-5.csv')
del users87['Unnamed: 0']

users88 = pd.read_csv('Sagar4.csv')
del users88['Unnamed: 0']

users71.head()
# Out:
#                                   Name  Restaurant  \
# 0                             KeikoESH  Palm Court
# 1      tommye618London, United Kingdom  Palm Court
# 2                             GB181818  Palm Court
# 3        mik4647London, United Kingdom  Palm Court
# 4  rovingalisonCardiff, United Kingdom  Palm Court
#
#                                              Rating
# 0  <span class="ui_bubble_rating bubble_20"></span>
# 1  <span class="ui_bubble_rating bubble_50"></span>
# 2  <span class="ui_bubble_rating bubble_50"></span>
# 3  <span class="ui_bubble_rating bubble_50"></span>
# 4  <span class="ui_bubble_rating bubble_50"></span>

# %%
users89 = pd.read_csv('Mrare-01.csv')
del users89['Unnamed: 0']

users90 = pd.read_csv('Mrare-02.csv')
del users90['Unnamed: 0']

# %%
users = pd.concat([users1, users2, users3, users4, users5, users6, users7, users8, users9, users10, users11,
                           users12, users13, users14, users15, users16, users17, users18, users19, users20, users21,
                           users22, users23, users24, users25, users26, users27, users28, users29, users30, users31, users32, users33,
                           users34, users35, users36, users37, users38, users39, users40, users41, users42, users43,
                           users44, users45, users46, users47, users48, users49, users50, users51, users52, users53, users54, users55,
                           users56, users57, users58, users59, users60, users61, users62, users63, users64, users65,
                           users66, users67, users68, users69, users70, users71, users72, users73, users74, users75, users76, users77,
                           users78, users79, users80, users81, users82, users83, users84, users85, users86, users87,
                           users88, users89, users90, users91], axis = 0)

# %%
users.shape
# Out:
# (1614890, 3)

# %%
users = users.drop_duplicates(subset=None, keep='first', inplace=False)
users.shape
# Out:
# (1532644, 3)

# %%
users.Name.value_counts()[:200000]
# Out:
# A TripAdvisor reviewer on Facebook                          1069
# A TripAdvisor reviewer on FacebookLondon, United Kingdom     666
# futtock21London, United Kingdom                              629
# beverleydaveLondon, United Kingdom                           403
# sheepygoldlondon                                             393
# davethedrillHemel Hempstead, United Kingdom                  266
# 996junerLondon, United Kingdom                               250
# fabsiteLondon, United Kingdom                                225
# LargelyMonkBanstead, United Kingdom                          224
# SaintlysinnerLondon, United Kingdom                          215
# Peter TLondon, United Kingdom                                213
# nomadladLondon, United Kingdom                               196
# SidjiLondon, United Kingdom                                  195
# James LLondon, United Kingdom                                189
# ...

# %%
#number of unique restaurants
users['Restaurant'].nunique()
# Out:
# 13586

# %%
#number of unqiue users
users['Name'].nunique()
# Out:
# 716655

# %%
users.dropna(inplace=True)

# %%
users.shape
# Out:
# (1532640, 3)

# %%
#Extracting the rating and scaling the rating to scale 0-5
users['Rating'] = users.Rating.str.extract('(\d+)')
users['Rating'] = users['Rating'].apply(lambda x : float(x)/10)
users.head()
# Out:
#                                  Name                 Restaurant  Rating
# 0  Dr_Rebecca_PLondon, United Kingdom  Street Feast Model Market     4.0
# 1         Karen GKent, United Kingdom  Street Feast Model Market     2.0
# 2       MelMayBLondon, United Kingdom  Street Feast Model Market     3.0
# 3         madfordrMississauga,Ontario  Street Feast Model Market     5.0
# 4      kerlee18London, United Kingdom  Street Feast Model Market     4.0

# %%
users.to_csv('users_clean.csv', index=True)

# %%
users = pd.read_csv('users_clean.csv')
del users['Unnamed: 0']
users.head()
# Out:
#                                  Name                 Restaurant  Rating
# 0  Dr_Rebecca_PLondon, United Kingdom  Street Feast Model Market     4.0
# 1         Karen GKent, United Kingdom  Street Feast Model Market     2.0
# 2       MelMayBLondon, United Kingdom  Street Feast Model Market     3.0
# 3         madfordrMississauga,Ontario  Street Feast Model Market     5.0
# 4      kerlee18London, United Kingdom  Street Feast Model Market     4.0

# %%
users[users.Restaurant == "Tossed"]
# Out:
#                                               Name Restaurant  Rating
# 665247         katiedJ1465GMLondon, United Kingdom     Tossed     5.0
# 665248                MicheleLivornoLivorno, Italy     Tossed     5.0
# 665249            cardamomssLondon, United Kingdom     Tossed     5.0
# 665250              rubypawsLondon, United Kingdom     Tossed     5.0
# 691734          VANTERHEYDENLondon, United Kingdom     Tossed     5.0
# 691735              Ace28065London, United Kingdom     Tossed     5.0
# 691736                LewieLewieLewieParis, France     Tossed     4.0
# 691737                  P3ZZ6Essex, United Kingdom     Tossed     3.0
# 691738              Ace28065London, United Kingdom     Tossed     4.0
# 691739          Sinclair0504London, United Kingdom     Tossed     2.0
# 711652            jaronningEden Prairie, Minnesota     Tossed     4.0
# 711653                                  Maps482807     Tossed     1.0
# ...

# %%
print("The number of restaurants is {}.".format(users.Restaurant.nunique()))
print("The number of users is {}.".format(users.Name.nunique()))
print("The number of ratings is {}.".format(users.shape[0]))
# Out:
# The number of restaurants is 13586.
# The number of users is 716655.
# The number of ratings is 1532640.

# %%
#Load unique dictionary names
import pickle
infile = open('restaurant_dict.pkl','rb')
restaurant_dict = pickle.load(infile)
infile.close()

# %%
#Number of restaurants not in our restaurant dictionary
print(np.setdiff1d(np.array(users['Restaurant'].unique()), np.array(list(restaurant_dict.keys()))))
missing_names = (np.setdiff1d(np.array(users['Restaurant'].unique()), np.array(list(restaurant_dict.keys()))))
# Out:
# ['90 Degree MELT\xa0-\xa0CLOSED   ' 'Afternoon Tea  At Grand Royale'
#  'Ambala\xa0-\xa0CLOSED   ' 'Anzu\xa0-\xa0CLOSED   ' "Arlo's Balham"
#  'BA Restaurant  Chiswick' 'Barbecoa\xa0-\xa0CLOSED   '
#  "Berluskoni's\xa0-\xa0CLOSED   " 'Bica Coffee\xa0-\xa0CLOSED   '
#  'Burger Bear\xa0-\xa0CLOSED   ' 'Byron Kingston' 'Cafe  Anglais'
#  'China City  - Russell Square' 'Choccywoccydoodah\xa0-\xa0CLOSED   '
#  'Chucs Cafe Serpentine' 'Chucs Mayfair' 'Ciao Ciao Club' 'Cicchetti'
#  'Corus  Hyde Park' 'Dash\xa0-\xa0CLOSED   ' 'Eat\xa0-\xa0CLOSED   '
#  'Fondue Lodge\xa0-\xa0CLOSED   ' "Frank's\xa0-\xa0CLOSED   "
#  'Frankies  Sandwich  Bar' 'Good Hope Cafe Hither Green'
#  'Happy Pizza\xa0-\xa0CLOSED   ' 'Hooked Fish and Grill'
#  'Italo  Delicatessen' 'Jamies - St Mary at Hill'
#  'Kabylie Cafe\xa0-\xa0CLOSED   ' 'Konditor' 'La Cucina\xa0-\xa0CLOSED   '
#  'Marathon Restaurant  and Bar' 'Muddy Boots  The Modern Company Co.'
# ...

# %%
#Number of restaurants name not present in restaurant_dict

print(len(np.setdiff1d(np.array(list(restaurant_dict.keys())), np.array(users['Restaurant'].unique()))))
# Out:
# 904

# %%
#Creating user_id for restaurants not present in our resturant_dict

14424 in restaurant_dict.values()

print(missing_names)

number = 14424

for i in missing_names:
    
    number += 1
    
    restaurant_dict[i] = number
# Out:
# ['90 Degree MELT\xa0-\xa0CLOSED   ' 'Afternoon Tea  At Grand Royale'
#  'Ambala\xa0-\xa0CLOSED   ' 'Anzu\xa0-\xa0CLOSED   ' "Arlo's Balham"
#  'BA Restaurant  Chiswick' 'Barbecoa\xa0-\xa0CLOSED   '
#  "Berluskoni's\xa0-\xa0CLOSED   " 'Bica Coffee\xa0-\xa0CLOSED   '
#  'Burger Bear\xa0-\xa0CLOSED   ' 'Byron Kingston' 'Cafe  Anglais'
#  'China City  - Russell Square' 'Choccywoccydoodah\xa0-\xa0CLOSED   '
#  'Chucs Cafe Serpentine' 'Chucs Mayfair' 'Ciao Ciao Club' 'Cicchetti'
#  'Corus  Hyde Park' 'Dash\xa0-\xa0CLOSED   ' 'Eat\xa0-\xa0CLOSED   '
#  'Fondue Lodge\xa0-\xa0CLOSED   ' "Frank's\xa0-\xa0CLOSED   "
#  'Frankies  Sandwich  Bar' 'Good Hope Cafe Hither Green'
#  'Happy Pizza\xa0-\xa0CLOSED   ' 'Hooked Fish and Grill'
#  'Italo  Delicatessen' 'Jamies - St Mary at Hill'
#  'Kabylie Cafe\xa0-\xa0CLOSED   ' 'Konditor' 'La Cucina\xa0-\xa0CLOSED   '
#  'Marathon Restaurant  and Bar' 'Muddy Boots  The Modern Company Co.'
# ...

# %%
restaurant_dict['The Ritz Restaurant']
# Out:
# 14482

# %%
#Creating Restaurant id from our restaurant dictionary
users['Restaurant_id'] = users['Restaurant'].map(restaurant_dict)

# %%
users.head()
# Out:
#                                  Name                 Restaurant  Rating  \
# 0  Dr_Rebecca_PLondon, United Kingdom  Street Feast Model Market     4.0
# 1         Karen GKent, United Kingdom  Street Feast Model Market     2.0
# 2       MelMayBLondon, United Kingdom  Street Feast Model Market     3.0
# 3         madfordrMississauga,Ontario  Street Feast Model Market     5.0
# 4      kerlee18London, United Kingdom  Street Feast Model Market     4.0
#
#    Restaurant_id
# 0           3468
# 1           3468
# 2           3468
# 3           3468
# 4           3468

# %%
#Creating unique user_ids

print('The number of unique user names are {}' .format(users['Name'].nunique()))


#Dictionary for mapping restuarant to unique ids
users_dict = {}


for id, name in enumerate(users['Name'].unique(), 1):
    
    users_dict[name] = id
    

users_dict
# Out:
# The number of unique user names are 716655
# {'Dr_Rebecca_PLondon, United Kingdom': 1,
#  'Karen GKent, United Kingdom': 2,
#  'MelMayBLondon, United Kingdom': 3,
#  'madfordrMississauga,Ontario': 4,
#  'kerlee18London, United Kingdom': 5,
#  'booms222London, United Kingdom': 6,
#  'si0nakLondon, United Kingdom': 7,
#  '1Emily_JSLondon, United Kingdom': 8,
#  'Large1968Mansfield, United Kingdom': 9,
#  'dbR5901SQ': 10,
#  'TravelStar02London': 11,
#  'Merrin HLondon, England, United Kingdom': 12,
#  'LeoPepsLondon, United Kingdom': 13,
#  'KennyTinsel': 14,
#  'jennylcNgGreater London, United Kingdom': 15,
#  'Rainman1957London, United Kingdom': 16,
#  'Paul WLondon, United Kingdom': 17,
#  'LlanelliclaireandjoePlaya de las Americas, Spain': 18,
#  '886AndrewTLondon, United Kingdom': 19,
#  'Cristynangharad': 20,
#  '873AmyB873London, United Kingdom': 21,
#  'W2734ZIwilliambLondon, United Kingdom': 22,
#  'stanleym897': 23,
#  'ksnshxhvssUnited Kingdom': 24,
#  'Loreana P': 25,
# ...

# %%
#Creating user id from our restaurant dictionary
users['User_id'] = users['Name'].map(users_dict)
users.head()
# Out:
#                                  Name                 Restaurant  Rating  \
# 0  Dr_Rebecca_PLondon, United Kingdom  Street Feast Model Market     4.0
# 1         Karen GKent, United Kingdom  Street Feast Model Market     2.0
# 2       MelMayBLondon, United Kingdom  Street Feast Model Market     3.0
# 3         madfordrMississauga,Ontario  Street Feast Model Market     5.0
# 4      kerlee18London, United Kingdom  Street Feast Model Market     4.0
#
#    Restaurant_id  User_id
# 0           3468        1
# 1           3468        2
# 2           3468        3
# 3           3468        4
# 4           3468        5

# %%
#Rearranging our columns

new_order = [0, 4, 1, 3, 2]

users = users[users.columns[new_order]]

#rearranged columns
users.head()
# Out:
#                                  Name  User_id                 Restaurant  \
# 0  Dr_Rebecca_PLondon, United Kingdom        1  Street Feast Model Market
# 1         Karen GKent, United Kingdom        2  Street Feast Model Market
# 2       MelMayBLondon, United Kingdom        3  Street Feast Model Market
# 3         madfordrMississauga,Ontario        4  Street Feast Model Market
# 4      kerlee18London, United Kingdom        5  Street Feast Model Market
#
#    Restaurant_id  Rating
# 0           3468     4.0
# 1           3468     2.0
# 2           3468     3.0
# 3           3468     5.0
# 4           3468     4.0

# %%
users.to_csv('users_extra.csv', index=True)

# %%
del users['Name']
del users['Restaurant']
users.to_csv('users.csv', index=True)
users.head()
# Out:
#    User_id  Restaurant_id  Rating
# 0        1           3468     4.0
# 1        2           3468     2.0
# 2        3           3468     3.0
# 3        4           3468     5.0
# 4        5           3468     4.0
