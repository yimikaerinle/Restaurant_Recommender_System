# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set(font_scale=1.5)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# this line tells jupyter notebook to put the plots in the notebook rather than saving them to file
# %matplotlib inline

# this line makes plots prettier on mac retina screens - if you don't have one it shouldn't do anything
# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
import numpy as np
import re

food = pd.read_csv('restau_london_final.csv', index_col=1)
del food['Unnamed: 0']
del food['Url']
food.head()
# Out:
#                      Review          Rating Category 1  \
# Name
# Amrutha Lounge  425 reviews  5 of 5 bubbles     Indian
# Barge East      184 reviews  5 of 5 bubbles   European
# Latitude         78 reviews  5 of 5 bubbles   European
# Dobar           107 reviews  5 of 5 bubbles      Pizza
# Chojo           199 reviews  5 of 5 bubbles    Chinese
#
#                                                        Category 2
# Name
# Amrutha Lounge  ££ - £££\nIndian\nAsian\nHealthy\nVegetarian F...
# Barge East      ££ - £££\nEuropean\nBritish\nContemporary\nFus...
# Latitude        ££ - £££\nEuropean\nInternational\nBritish\nVe...
# Dobar           ££ - £££\nPizza\nCafe\nBritish\nVegetarian Fri...
# Chojo           ££ - £££\nChinese\nTaiwanese\nStreet Food\nVeg...

# %%
food.dropna(inplace=True)

# %%
food.Review = [int(x.replace(',', '').replace('reviews','').replace('review','')) for x in food.Review]
food.Rating = [float(str(x).replace('of 5 bubbles', '')) for x in food.Rating]
food = food[food.Rating != -1]

# %%
food['Category 2'] = [str(x).replace('££ - £££\n','').replace('£\n', '').replace('£££', '').replace('\n', ',').replace(',', ' ') for x in food['Category 2']]
food['Category 2'].head()
# Out:
# Name
# Amrutha Lounge    Indian Asian Healthy Vegetarian Friendly Vegan...
# Barge East        European British Contemporary Fusion Vegetaria...
# Latitude          European International British Vegetarian Frie...
# Dobar             Pizza Cafe British Vegetarian Friendly Vegan O...
# Chojo             Chinese Taiwanese Street Food Vegetarian Frien...
# Name: Category 2, dtype: object

# %%
food.head()
# Out:
#                 Review  Rating Category 1  \
# Name
# Amrutha Lounge     425     5.0     Indian
# Barge East         184     5.0   European
# Latitude            78     5.0   European
# Dobar              107     5.0      Pizza
# Chojo              199     5.0    Chinese
#
#                                                        Category 2
# Name
# Amrutha Lounge  Indian Asian Healthy Vegetarian Friendly Vegan...
# Barge East      European British Contemporary Fusion Vegetaria...
# Latitude        European International British Vegetarian Frie...
# Dobar           Pizza Cafe British Vegetarian Friendly Vegan O...
# Chojo           Chinese Taiwanese Street Food Vegetarian Frien...

# %%
lst = [re.findall('V........n', x) for x in food['Category 2']]

# %%
new_list = []
for i in lst:
    try:
        if i[0] == 'Vegetarian':
            new_list.append('Vegetarian')
        else:
            new_list.append('Non-Vegetarian')
    except:
        new_list.append('Non-Vegetarian')

# %%
food['Category 2'] = new_list

# %%
food['Category 1'].value_counts().head()
# Out:
# British     1963
# Italian     1648
# Cafe        1295
# Indian      1079
# European     726
# Name: Category 1, dtype: int64

# %%
food['Category 1'].unique()
# Out:
# array(['Indian', 'European', 'Pizza', 'Chinese', 'German', 'French',
#        'Italian', 'Mediterranean', 'British', 'Seafood', 'International',
#        'Fast food', 'Steakhouse', 'Japanese', 'Cafe',
#        'Vegetarian Friendly', 'Moroccan', 'American', 'Mexican',
#        'Taiwanese', 'African', 'Asian', 'South American', 'Irish',
#        'Fusion', 'Middle Eastern', 'Latin', 'Vietnamese', 'Lebanese',
#        'Thai', 'Greek', 'Spanish', 'Barbecue', 'Caribbean', 'Polish',
#        'Peruvian', 'Argentinian', 'Turkish', 'Venezuelan',
#        'Cajun & Creole', 'Healthy', 'Philippine', 'Deli', 'Portuguese',
#        'Sushi', 'Street Food', 'Burmese', 'Vegan Options', 'Malaysian',
#        'Soups', 'Russian', 'Persian', 'Eastern European', 'Korean',
#        'Gluten Free Options', 'Cuban', 'Pakistani', 'Halal', 'Hawaiian',
#        'Kosher', 'Arabic', 'Ethiopian', 'Jamaican'], dtype=object)

# %%
other = ['Fast food', 'Seafood', 'International', 'Steakhouse', 'Cafe',  'Vegetarian Friendly', 'Street Food',
        'Fusion', 'Barbecue', 'Healthy', 'Deli', 'Vegan Options', 'Pizza', 'Sushi', 'Soups', 'Gluten Free Options']
east_euro = ['Russian', 'Polish']
euro = ['Irish', 'German', 'French', 'Latin', 'Greek', 'Portuguese']
s_american = ['Peruvian', 'Argentinian', 'Venezuelan', 'Cuban']
african = ['Cajun & Creole', 'Moroccan', 'Ethiopian']
asian = ['Philippine', 'Taiwanese', 'Pakistani', 'Korean', 'Vietnamese']
med = ['Persian', 'Malaysian', 'Burmese']
mid_east = ['Arabic', 'Kosher', 'Halal']

# %%
def classifier_other(x):

    if x in other:
        return 'General'
    elif x in east_euro:
        return 'Eastern European'
    elif x in euro:
        return 'European'
    elif x in s_american:
        return 'South American'
    elif x in african:
        return 'African'
    elif x in med:
        return 'Mediterranean'
    elif x in asian:
        return 'Asian'
    elif x in mid_east:
        return 'Middle Eastern'
    elif x == 'Jamaican':
        return 'Caribbean'
    elif x == 'Hawaiian':
        return 'American'
    else:
        return x

# %%
food['Category 1'] = food['Category 1'].apply(classifier_other)

# %%
food.head(20)
# Out:
#                                      Review  Rating     Category 1  \
# Name
# Amrutha Lounge                          425     5.0         Indian
# Barge East                              184     5.0       European
# Latitude                                 78     5.0       European
# Dobar                                   107     5.0        General
# Chojo                                   199     5.0        Chinese
# German Doner Kebab                      146     5.0       European
# Bistro Mirey                             81     5.0       European
# Core by Clare Smyth                     546     5.0       European
# Buongiorno e Buonasera                  234     5.0        Italian
# Taste Of Nawab                          827     5.0         Indian
# Room 43 Bar & Kitchen                    98     5.0  Mediterranean
# The Lounge Cafe                         186     5.0        British
# Pizza Pickup                            121     5.0        Italian
# The Rajdoot                             101     5.0         Indian
# Andy's Greek Taverna                   1322     5.0  Mediterranean
# The Golden Chippy                      1519     5.0        General
# Oliveira Organic Vegetarian Kitchen     140     5.0        General
# Midpoint Restaurant                     274     5.0  Mediterranean
# Piatto                                  105     5.0        Italian
# The Clink Restaurant                    866     5.0       European
#
#                                          Category 2
# Name
# Amrutha Lounge                           Vegetarian
# Barge East                               Vegetarian
# Latitude                                 Vegetarian
# Dobar                                    Vegetarian
# Chojo                                    Vegetarian
# German Doner Kebab                   Non-Vegetarian
# Bistro Mirey                             Vegetarian
# Core by Clare Smyth                      Vegetarian
# Buongiorno e Buonasera                   Vegetarian
# Taste Of Nawab                           Vegetarian
# Room 43 Bar & Kitchen                    Vegetarian
# The Lounge Cafe                          Vegetarian
# Pizza Pickup                             Vegetarian
# The Rajdoot                              Vegetarian
# Andy's Greek Taverna                     Vegetarian
# The Golden Chippy                    Non-Vegetarian
# Oliveira Organic Vegetarian Kitchen      Vegetarian
# Midpoint Restaurant                      Vegetarian
# Piatto                                   Vegetarian
# The Clink Restaurant                     Vegetarian

# %%
data_dic = {
            'Data Columns': list(food.columns),
            'Data Types': ['Object','Integer','Float','Object', 'Object'],
            'Data Description': ['Restaurant Name','Review','Rating','Category 1', 'Category 2'],
            'Data Shape': list(food.shape)
}

data_dic
# Out:
# {'Data Columns': ['Review', 'Rating', 'Category 1', 'Category 2'],
#  'Data Types': ['Object', 'Integer', 'Float', 'Object', 'Object'],
#  'Data Description': ['Restaurant Name',
#   'Review',
#   'Rating',
#   'Category 1',
#   'Category 2'],
#  'Data Shape': [13291, 4]}

# %%
food.describe(include=['object','float','int'])
# Out:
#               Review        Rating Category 1  Category 2
# count   13291.000000  13291.000000      13291       13291
# unique           NaN           NaN         20           2
# top              NaN           NaN    General  Vegetarian
# freq             NaN           NaN       3113        6804
# mean      179.237755      3.994583        NaN         NaN
# std       433.701678      0.660227        NaN         NaN
# min         1.000000      1.000000        NaN         NaN
# 25%        13.000000      3.500000        NaN         NaN
# 50%        51.000000      4.000000        NaN         NaN
# 75%       175.000000      4.500000        NaN         NaN
# max     15253.000000      5.000000        NaN         NaN

# %%
print(food['Rating'].value_counts())
print(food['Category 1'].value_counts())
print(food['Category 2'].value_counts())
# Out:
# 4.0    4734
# 4.5    3557
# 3.5    2407
# 5.0    1238
# 3.0     782
# 2.5     292
# 2.0     151
# 1.0      76
# 1.5      54
# Name: Rating, dtype: int64
# General             3113
# British             1963
# Italian             1648
# European            1223
# Indian              1079
# Asian                653
# Chinese              642
# Mediterranean        593
# Japanese             546
# American             512
# Lebanese             246
# Turkish              187
# Middle Eastern       180
# Mexican              175
# Caribbean            129
# Thai                 113
# African              111
# Spanish               79
# South American        58
# Eastern European      41
# Name: Category 1, dtype: int64
# Vegetarian        6804
# Non-Vegetarian    6487
# Name: Category 2, dtype: int64

# %%
axe = food.Rating.plot(kind = 'hist', bins= 9, color= 'c')

axe.set_ylabel('Frequency')

axe.set_xlabel('Rating')
 
axe.set_title('Restaurant Rating Frequency')
# Out:
# Text(0.5, 1.0, 'Restaurant Rating Frequency')

# %%
grouped_by_cat1 = food.groupby('Category 1')
grouped_by_cat1.nunique()
# Out:
#                   Review  Rating  Category 1  Category 2
# Category 1
# African               74       8           1           2
# American             254       9           1           2
# Asian                278       8           1           2
# British              500       9           1           2
# Caribbean             68       9           1           2
# Chinese              238       9           1           2
# Eastern European      35       7           1           2
# European             580       9           1           2
# General              479       9           1           2
# Indian               335       9           1           2
# Italian              528       9           1           2
# Japanese             238       9           1           2
# Lebanese             145       8           1           2
# Mediterranean        315       7           1           2
# Mexican              115       9           1           2
# Middle Eastern       102       8           1           2
# South American        50       5           1           2
# Spanish               51       7           1           2
# Thai                  62       8           1           2
# Turkish               69       7           1           2

# %%
food.groupby('Category 1').size().plot(kind='bar', color='b', width=0.95, figsize=(16,8))
plt.xticks(rotation=90)
plt.show()

# %%
cat_review_mean = food.groupby(['Category 1', 'Rating'])[['Review']].mean()
cat_review_mean.unstack()
# Out:
#                     Review                                               \
# Rating                 1.0        1.5        2.0        2.5         3.0
# Category 1
# African           2.000000        NaN   5.000000   4.000000   20.000000
# American          1.400000   3.500000   7.000000  68.900000   65.043478
# Asian                  NaN  51.000000  38.800000  39.000000   79.594595
# British           1.400000  44.800000  31.625000  65.933333  107.898305
# Caribbean         1.000000   3.000000  11.000000  16.857143   38.000000
# Chinese           2.600000  16.818182  33.592593  37.560000   94.395062
# Eastern European       NaN        NaN   5.000000   4.000000   11.000000
# European          2.571429   3.000000  15.333333  65.555556  109.472222
# General           2.689655  11.857143  12.173077  24.732558   43.729730
# Indian            1.375000   3.000000  74.142857  34.300000   56.823529
# Italian           1.500000  61.666667  53.307692  15.250000  131.225352
# Japanese          1.666667   4.000000   1.800000  47.083333   70.576923
# Lebanese               NaN   3.000000   1.000000  95.000000   66.333333
# Mediterranean          NaN        NaN   1.000000  49.000000   63.285714
# Mexican           1.000000  26.500000  44.600000  25.285714   94.000000
# Middle Eastern    1.000000        NaN   1.000000  73.000000   51.500000
# South American         NaN        NaN        NaN        NaN    6.500000
# Spanish                NaN        NaN   5.000000   2.000000   29.600000
# Thai              1.000000        NaN  42.000000   6.000000   39.636364
# Turkish                NaN        NaN   6.666667  18.500000   14.200000
#
#
# Rating                   3.5         4.0         4.5         5.0
# Category 1
# African           688.785714  149.142857   91.341463   74.565217
# American          358.524752  384.982249  323.085714    9.272727
# Asian             167.680851  172.421818  112.574324   15.789474
# British           178.104938  205.977246  217.633838   13.526316
# Caribbean          62.100000  162.600000   48.482759    5.550000
# Chinese           201.932432  206.272251  140.318681   13.757576
# Eastern European   15.750000   93.357143  211.625000   17.250000
# European          243.681818  473.553015  433.656489   61.801802
# General            99.000000  161.995889  147.978214   25.798387
# Indian            107.423645  163.445026  242.981752   38.147727
# Italian           255.667808  268.124561  191.008065   39.145251
# Japanese          130.290000  228.375000  160.503650   33.760870
# Lebanese           85.307692  182.160494  152.635135   14.941176
# Mediterranean     149.849057  268.806763  232.971545  110.848485
# Mexican           160.555556  300.376623  444.100000   17.071429
# Middle Eastern     59.600000  104.793103  165.490196    7.533333
# South American    146.375000  478.583333  152.944444   56.666667
# Spanish            44.300000  101.551724  115.476190   12.916667
# Thai               87.411765  178.804348   64.560000    8.000000
# Turkish            58.533333   54.872727   65.672414   11.407407

# %%
cat_review_mean.unstack().plot(kind='bar', width=1.4, figsize=(20,12))
plt.legend(['1 Star', '1.5 Stars', '2 Stars', '2.5 Stars', '3 Stars', '3.5 Stars', '4 Stars', '4.5 Stars', '5 Stars'])
plt.xticks(rotation=90)
plt.show()

# %%
Rating = food.Rating

# %%
grouped_by_cat2 = food.groupby('Category 2')
grouped_by_cat2.nunique()
# Out:
#                 Review  Rating  Category 1  Category 2
# Category 2
# Non-Vegetarian     434       9          20           1
# Vegetarian        1153       7          20           1

# %%
cat2_review_mean = food.groupby(['Category 2', 'Rating'])[['Review']].mean()
cat2_review_mean.unstack()
# Out:
#                   Review                                                 \
# Rating               1.0        1.5         2.0         2.5         3.0
# Category 2
# Non-Vegetarian  2.144737  23.592593   22.194631   33.749104   38.522023
# Vegetarian           NaN        NaN  211.000000  122.923077  210.520710
#
#
# Rating                 3.5         4.0         4.5         5.0
# Category 2
# Non-Vegetarian   59.911909   71.313087   75.878470   10.209302
# Vegetarian      286.792549  335.036606  289.133993  111.044521

# %%
food.groupby('Category 2').size().plot(kind='bar', color='r', width=0.85, figsize=(16,8))
plt.xticks(rotation=0)
plt.show()

# %%
food.groupby(['Category 2', 'Rating'])['Review'].mean().plot(
    kind='bar', color='r', width=0.9, figsize=(16,8))
plt.xticks(rotation=90)
plt.show()

# %%
cat2_review_mean.unstack().plot(kind='bar', width=1.2, figsize=(16,8))
plt.legend(['1 Star', '1.5 Stars', '2 Stars', '2.5 Stars', '3 Stars', '3.5 Stars', '4 Stars', '4.5 Stars', '5 Stars'])
plt.xticks(rotation=0)
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
ax = fig.gca()

sns.boxplot(y='Rating',x='Category 1',data=food,
            )

plt.xticks(rotation=90)
ax.set_title('Rating Boxplot\n')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
fig = plt.figure(figsize=(12, 6))
ax = fig.gca()
food['reviews_standardise']=scaler.fit_transform(food[['Review']])
sns.boxplot(y='reviews_standardise',x='Category 1',data=food,
            )

plt.xticks(rotation=90)
ax.set_title('Restaurant Reviews Boxplot\n')
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
sns.boxplot(y='Review',x='Category 1',data=food,
            )

# %%
groupby=food.groupby(['Category 1'])
groupby
# Out:
#                       Review    Rating
# Category 1
# African           728.038093  0.758274
# American          631.462514  0.767129
# Asian             273.435148  0.541084
# British           459.722491  0.537272
# Caribbean         152.461122  0.850270
# Chinese           404.974789  0.833447
# Eastern European  222.002241  0.622740
# European          750.834618  0.573022
# General           330.896155  0.729635
# Indian            372.369563  0.660283
# Italian           340.818808  0.602946
# Japanese          366.399304  0.622953
# Lebanese          203.381592  0.606365
# Mediterranean     319.755848  0.486937
# Mexican           455.314133  0.723372
# Middle Eastern    274.609872  0.663961
# South American    439.123251  0.479463
# Spanish           139.046005  0.619912
# Thai              259.391929  0.652568
# Turkish           157.797629  0.647865

# %%
fig = plt.figure(figsize=(12, 6))
ax = fig.gca()

sns.boxplot(y='Rating',x='Category 2',data=food,
            )

plt.xticks(rotation=90)
ax.set_title('Rating Boxplot\n')
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
ax = fig.gca()

sns.boxplot(data=food['Rating'], orient='h', fliersize=3, linewidth=3, notch=True,
            saturation=0.5, ax=ax)

ax.set_title('Rating Boxplot\n')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(food[['Rating','Review']].corr(), annot=True)
plt.show()

# %%
cringe = food
cringe = cringe[cringe['Rating'] >= 4.0]
crin_review_mean = cringe.groupby(['Category 1', 'Rating'])[['Review']].mean()
crin_review_mean.unstack().plot(kind='bar', width=1.0, figsize=(20,12))
plt.legend(['4 Stars', '4.5 Stars', '5 Stars'])
plt.xticks(rotation=90)
plt.show()
